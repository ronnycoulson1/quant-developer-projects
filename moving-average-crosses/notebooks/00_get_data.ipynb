# %% [markdown]
# # Project Requirements: Moving Average Crossover Strategy
#
# ## ✅ Data Source
#
# - Use the `yfinance` API to fetch historical price data.
# - Ensure **24/7 coverage** if applying this to **crypto** markets.
#
# ## ⏱️ Time Frame
#
# - Minimum **50 days** of data required for short-term moving average.
# - **Recommended:** 200+ days for long-term trend analysis and reliable crossover signals.
#
# ## 📊 Required Data Columns
#
# - Essential columns:
#   - `Open`
#   - `High`
#   - `Low`
#   - `Close`
#   - `Volume`
# - For crypto:
#   - Check if `Adj Close` is available or if regular `Close` should be used.
#
# ## 🧹 Missing Data Handling
#
# - Identify gaps in timestamps.
# - Handle missing values using:
#   - **Forward fill**
#   - **Linear interpolation**
#   - **Dropping incomplete days** (if necessary)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\ronny\anaconda3\lib\site-packages (3.9.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ronny\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ronny\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ronny\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ronny\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\ronny\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ronny\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ronny\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ronny\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ronny\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ronny\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# %pip install yfinance
# Out:
# Requirement already satisfied: yfinance in c:\users\ronny\anaconda3\lib\site-packages (0.2.61)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (0.11.1)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (4.25.3)
# Requirement already satisfied: websockets>=13.0 in c:\users\ronny\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ronny\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\ronny\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in c:\users\ronny\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ronny\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ronny\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ronny\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ronny\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ronny\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.2.3)
# Requirement already satisfied: pycparser in c:\users\ronny\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\ronny\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
btc_usd = yf.Ticker("BTC-USD") #get data
hist = btc_usd.history(period = "max") #check historical data
print(hist.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2014-09-17 00:00:00+00:00  465.864014  468.174011  452.421997  457.334015
# 2014-09-18 00:00:00+00:00  456.859985  456.859985  413.104004  424.440002
# 2014-09-19 00:00:00+00:00  424.102997  427.834991  384.532013  394.795990
# 2014-09-20 00:00:00+00:00  394.673004  423.295990  389.882996  408.903992
# 2014-09-21 00:00:00+00:00  408.084991  412.425995  393.181000  398.821014
#
#                              Volume  Dividends  Stock Splits
# Date
# 2014-09-17 00:00:00+00:00  21056800        0.0           0.0
# 2014-09-18 00:00:00+00:00  34483200        0.0           0.0
# 2014-09-19 00:00:00+00:00  37919700        0.0           0.0
# 2014-09-20 00:00:00+00:00  36863600        0.0           0.0
# 2014-09-21 00:00:00+00:00  26580100        0.0           0.0

# %%
#get the actual date 
type(btc_usd)
df = btc_usd.history(period= "60d") #60 days 
df = df.reset_index() # this line help get the date on column
df.head(10) # give me 10  first ones
# Out:
#                        Date          Open          High           Low  \
# 0 2025-04-08 00:00:00+00:00  79218.476562  80823.890625  76198.023438
# 1 2025-04-09 00:00:00+00:00  76273.562500  83541.000000  74589.671875
# 2 2025-04-10 00:00:00+00:00  82565.976562  82700.929688  78456.132812
# 3 2025-04-11 00:00:00+00:00  79625.046875  84247.476562  78936.320312
# 4 2025-04-12 00:00:00+00:00  83404.515625  85856.187500  82769.375000
# 5 2025-04-13 00:00:00+00:00  85279.468750  86015.187500  83027.007812
# 6 2025-04-14 00:00:00+00:00  83694.523438  85785.000000  83690.640625
# 7 2025-04-15 00:00:00+00:00  84539.695312  86429.351562  83598.820312
# 8 2025-04-16 00:00:00+00:00  83674.507812  85428.281250  83100.617188
# 9 2025-04-17 00:00:00+00:00  84030.671875  85449.070312  83749.750000
#
#           Close       Volume  Dividends  Stock Splits
# 0  76271.953125  48314590749        0.0           0.0
# 1  82573.953125  84213627038        0.0           0.0
# 2  79626.140625  44718000633        0.0           0.0
# 3  83404.835938  41656778779        0.0           0.0
# 4  85287.109375  24258059104        0.0           0.0
# 5  83684.976562  28796984817        0.0           0.0
# 6  84542.390625  34090769777        0.0           0.0
# 7  83668.992188  28040322885        0.0           0.0
# 8  84033.867188  29617804112        0.0           0.0
# 9  84895.750000  21276866029        0.0           0.0

# %%
#get the actual date 
type(btc_usd)
df = btc_usd.history(period= "50d")
df = df.reset_index()
df.head(10) #
df = df.drop(columns=["Dividends", "Stock Splits"]) # drop dividens and stock_splits 
df.head(10)
print(df.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.head(10)
# Out:
#                        Date          Open          High           Low  \
# 0 2025-04-18 00:00:00+00:00  84900.187500  85095.046875  84298.882812
# 1 2025-04-19 00:00:00+00:00  84450.867188  85597.703125  84353.460938
# 2 2025-04-20 00:00:00+00:00  85066.070312  85306.382812  83976.843750
# 3 2025-04-21 00:00:00+00:00  85171.539062  88460.093750  85143.835938
# 4 2025-04-22 00:00:00+00:00  87521.875000  93817.382812  87084.531250
# 5 2025-04-23 00:00:00+00:00  93427.585938  94535.734375  91962.960938
# 6 2025-04-24 00:00:00+00:00  93692.398438  94016.195312  91696.710938
# 7 2025-04-25 00:00:00+00:00  93954.250000  95768.390625  92898.593750
# 8 2025-04-26 00:00:00+00:00  94714.648438  95251.359375  93927.250000
# 9 2025-04-27 00:00:00+00:00  94660.906250  95301.203125  93665.398438
#
#           Close       Volume
# 0  84450.804688  12728372364
# 1  85063.414062  15259300427
# 2  85174.304688  14664050812
# 3  87518.906250  41396190190
# 4  93441.890625  55899038456
# 5  93699.109375  41719568821
# 6  93943.796875  31483175315
# 7  94720.500000  40915232364
# 8  94646.929688  17612825123
# 9  93754.843750  18090367764

# %%
from datetime import date, timedelta
date_column = df["Date"]
date_column.head(10)
duration  = timedelta(days=50)  #50 days range 
today = date.today()            #today dates

# %%
past_dates = today - duration  # 50 days ago date equation

# %%
print(past_dates) #50 days ago
print(f"Todays date: {today}") # this date is from we are analyzing
print(f"50 days ag0 date: {past_dates}")
# Out:
# 2025-04-17
# Todays date: 2025-06-06
# 50 days ag0 date: 2025-04-17

# %%
def data():
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3     print(f"Todays date: {today}") # this date is from we are analyzing
#       4     print(f"50 days ag0 date: {past_dates}")
# ----> 6 data()
#
# Cell In[1], line 2, in data()
#       1 def data():
# ----> 2     print(past_dates) #50 days ago
#       3     print(f"Todays date: {today}") # this date is from we are analyzing
#       4     print(f"50 days ag0 date: {past_dates}")
#
# NameError: name 'past_dates' is not defined
